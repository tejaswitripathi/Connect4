# %%
# %run compare_agents.py
# Out:
# Playing Minimax vs Random...
#
# Playing game 1/100
# Minimax wins!
#
# Playing game 2/100
# Random wins!
#
# Playing game 3/100
# Minimax wins!
#
# Playing game 4/100
# Minimax wins!
#
# Playing game 5/100
# Minimax wins!
#
# Playing game 6/100
# Random wins!
#
# Playing game 7/100
# Random wins!
#
# Playing game 8/100
# Minimax wins!
#
# Playing game 9/100
# Minimax wins!
#
# Playing game 10/100
# Random wins!
#
# Playing game 11/100
# Minimax wins!
#
# Playing game 12/100
# Minimax wins!
#
# Playing game 13/100
# Minimax wins!
#
# Playing game 14/100
# Minimax wins!
#
# Playing game 15/100
# Random wins!
#
# Playing game 16/100
# Minimax wins!
#
# Playing game 17/100
# Minimax wins!
#
# Playing game 18/100
# Minimax wins!
#
# Playing game 19/100
# Random wins!
#
# Playing game 20/100
# Random wins!
#
# Playing game 21/100
# Random wins!
#
# Playing game 22/100
# Random wins!
#
# Playing game 23/100
# Random wins!
#
# Playing game 24/100
# Random wins!
#
# Playing game 25/100
# ...

# %%
# %run connect4_nn.py
# Out:
# Starting reinforcement learning training...
# Game 1/1000, Reward: 1.0, Loss: 33.1134
# Game 2/1000, Reward: -1.0, Loss: -1.2573
# Game 3/1000, Reward: 1.0, Loss: 21.9447
# Game 4/1000, Reward: 1.0, Loss: 11.1890
# Game 5/1000, Reward: 1.0, Loss: 13.4360
# Game 6/1000, Reward: 1.0, Loss: 0.5317
# Game 7/1000, Reward: 1.0, Loss: 0.8418
# Game 8/1000, Reward: 1.0, Loss: 0.8401
# Game 9/1000, Reward: 1.0, Loss: 7.9168
# Game 10/1000, Reward: 1.0, Loss: 7.9286
# Game 11/1000, Reward: 1.0, Loss: 5.0565
# Game 12/1000, Reward: 1.0, Loss: 1.8412
# Game 13/1000, Reward: 1.0, Loss: 6.8133
# Game 14/1000, Reward: 1.0, Loss: 0.0026
# Game 15/1000, Reward: 1.0, Loss: 3.6129
# Game 16/1000, Reward: 1.0, Loss: 0.0012
# Game 17/1000, Reward: -1.0, Loss: -19.6050
# Game 18/1000, Reward: 1.0, Loss: 0.0004
# Game 19/1000, Reward: 1.0, Loss: 0.0010
# Game 20/1000, Reward: 1.0, Loss: 0.8641
# Game 21/1000, Reward: 1.0, Loss: 2.4312
# Game 22/1000, Reward: 1.0, Loss: 1.7058
# ...
